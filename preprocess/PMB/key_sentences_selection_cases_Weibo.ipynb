# %% [markdown]
# # Claim-sentence Relevance

# %% [markdown]
# ## Loading

# %%
import torch
from tqdm import tqdm
import json
import random

# %%
fn_static_embeddings = torch.load(
    '../ROT/data/Weibo/FN_bert-base-chinese_embeddings_static.pt')
fn_dynamic_embeddings = torch.load(
    '../ROT/data/Weibo/FN_bert-base-chinese_embeddings_dynamic.pt')
dn_static_embeddings = torch.load(
    '../ROT/data/Weibo/DN_bert-base-chinese_embeddings_static.pt')
dn_dynamic_embeddings = torch.load(
    '../ROT/data/Weibo/DN_bert-base-chinese_embeddings_dynamic.pt')

len(fn_static_embeddings), len(fn_dynamic_embeddings), len(dn_static_embeddings), len(dn_dynamic_embeddings)
# Out:
# (11934, 11934, 27505, 27505)

# %%
with open('../../dataset/Weibo/raw/FN_11934_filtered.json', 'r') as f:
    FN = json.load(f)

with open('../../dataset/Weibo/raw/DN_27505_filtered.json', 'r') as f:
    DN = json.load(f)

fnOid2item = {fn['_id']: fn for fn in FN}
dnOid2item = {dn['_id']: dn for dn in DN}

fnIdx2item = {i: fn for i, fn in enumerate(FN)}
dnIdx2item = {i: dn for i, dn in enumerate(DN)}

fnOid2idx = {fn['_id']: i for i, fn in enumerate(FN)}
dnOid2idx = {dn['_id']: i for i, dn in enumerate(DN)}

len(FN), len(DN)
# Out:
# (11934, 27505)

# %%
def pytorch_euclidean_distance(a, b):
    return torch.dist(a, b)

# %%
def get_sim_scores(fn_emb, dn_emb):
    score_dict = dict()

    for qidx, fn in enumerate(tqdm(FN)):
        dn_oids = fn['debunking_ids']

        for did in dn_oids:
            dn = dnOid2item[did]
            didx = dnOid2idx[did]

            query = fn_emb[qidx]
            sentences = dn_emb[didx]

            items = [pytorch_euclidean_distance(
                query, sent) for sent in sentences]

            # Scale
            m, M = min(items), max(items)
            items = [1 - (x - m) / (M - m + 1e-8) for x in items]

            if qidx not in score_dict.keys():
                score_dict[qidx] = {didx: items}
            else:
                score_dict[qidx][didx] = items
                
    return score_dict

# %%
scores_dynamic = get_sim_scores(fn_dynamic_embeddings, dn_dynamic_embeddings)
# Out:
# 100%|██████████| 11934/11934 [00:46<00:00, 258.20it/s]

# %%
scores_static = get_sim_scores(fn_static_embeddings, dn_static_embeddings)
# Out:
# 100%|██████████| 11934/11934 [00:46<00:00, 253.97it/s]

# %%
def print_in_color(s, cint=31, end='\n'):
    print('\x1b[{}m{}\x1b[0m'.format(cint, s), end=end)

# %%
sorted(scores_dynamic[0][19], reverse=True)
# Out:
# [tensor(1.),
#  tensor(0.9864),
#  tensor(0.9283),
#  tensor(0.8933),
#  tensor(0.8823),
#  tensor(0.7885),
#  tensor(0.7509),
#  tensor(0.7465),
#  tensor(0.7306),
#  tensor(0.7234),
#  tensor(0.7197),
#  tensor(0.7056),
#  tensor(0.6803),
#  tensor(0.6667),
#  tensor(0.6539),
#  tensor(0.6325),
#  tensor(0.6219),
#  tensor(0.5724),
#  tensor(0.5424),
#  tensor(0.5198),
#  tensor(0.4378),
#  tensor(0.3717),
#  tensor(0.3205),
#  tensor(0.1436),
#  tensor(0.)]

# %% [markdown]
# ## Compare Dynamic & Static

# %%
TOP = 3

qidx = random.randint(0, len(FN) - 1)
fn = FN[qidx]

print('[Fake News]\n{}'.format(fn['content_all']))

for did in fn['debunking_ids']:
    didx = dnOid2idx[did]
    dn = DN[didx]

    s_dynamic = scores_dynamic[qidx][didx]
    s_static = scores_static[qidx][didx]

    top_s_dynamic = sorted(s_dynamic, reverse=True)[:TOP]
    top_s_static = sorted(s_static, reverse=True)[:TOP]

    print('\n---------------------------------------------')
    print('qidx = {}, didx = {}\n'.format(qidx, didx))

    print('[Debunking News]')
    for j, sent in enumerate(dn['content_all']):
        print('[Sent-{}]['.format(j), end='')

        print_func = print_in_color if s_dynamic[j] in top_s_dynamic else print
        print_func('Dynamic: {:.3f}'.format(s_dynamic[j]), end='')

        print(', ', end='')

        print_func = print_in_color if s_static[j] in top_s_static else print
        print_func('Static: {:.3f}'.format(s_static[j]), end='')

        print(']\t{}'.format(sent))
# Out:
# [Fake News]
# 新冠病毒来源于美国的证据来了。应该是美国那家军事实验室泄露@魔法部之声 求大神解释
#
# ---------------------------------------------
# qidx = 11580, didx = 22830
#
# [Debunking News]
# [Sent-0][Dynamic: 0.839, Static: 0.581]	#每日疫情快报#【最新辟谣】1. 新型冠状病毒是实验室制造的生物武器？
# [Sent-1][Dynamic: 1.000, Static: 1.000]	辟谣：2月19日，在世卫组织东地中海区域办事处新闻发布会上，世卫组织东地中海区域主任称，没有证据表明新型冠状病毒是实验室制造的，也没有证据表明新冠病毒是以生物武器的身份制造出来的，新冠病毒来自动物界。
# [Sent-2][Dynamic: 0.484, Static: 0.316]	 2. 新冠肺炎预警人之一，艾芬医生去世？
# [Sent-3][Dynamic: 0.736, Static: 0.787]	辟谣：2月20日13时许，武汉经济广播官方微博发布消息称，2月20日中午12点44分，仍在一线工作的武汉市中心医院急诊科主任艾芬，利用午饭间隙，向所有关心关注她的朋友表示感谢。
# [Sent-4][Dynamic: 0.000, Static: 0.000]	 3. 网传江苏省学校3月2日陆续开学？
# [Sent-5][Dynamic: 0.685, Static: 0.611]	辟谣：这条信息来源于前几天网上流传的江苏某地开会会议讨论稿上的信息。
# [Sent-6][Dynamic: 0.370, Static: 0.339]	江苏省政府、省教育厅、市政府、市教育局等官方网站、微信公众号、微博等从未发布过类似信息。
# [Sent-7][Dynamic: 0.531, Static: 0.652]	江苏省教育厅只在2月6日发布过通知：根据疫情发展情况，省政府决定，全省各级各类学校(高校、中小学、中职学校、幼儿园、托育机构)2月底前不开学。
# [Sent-8][Dynamic: 0.282, Static: 0.509]	 【紧急寻人】最新患者同乘信息公示：1月31日：出租车，豫AA507Q，金水区总医院-金水区杨金路办事处新庄家园1月16日：火车，G518，武汉-信阳 2月8日：出租车，豫A1L7V6，中原区国棉四厂家属院-郑州市中心医院1月21日：火车，G3212，03号车厢，不详-郑州1月18日：飞机，A942，迪拜-北京1月31日：火车，Z190，武汉-郑州1月10日：火车，K735，郑州-巩义1月23日：火车，Z54，08号车厢，武汉-郑州百度APP搜索【新冠肺炎】或URL，了解更多新冠肺炎情况。

# %% [markdown]
# # Pattern-sentence Relevance

# %% [markdown]
# ## Loading

# %%
import torch
from tqdm import tqdm
import json
import random
import numpy as np
import pickle

# %%
with open('../../dataset/Weibo/raw/FN_11934_filtered.json', 'r') as f:
    FN = json.load(f)

with open('../../dataset/Weibo/raw/DN_27505_filtered.json', 'r') as f:
    DN = json.load(f)

fnOid2item = {fn['_id']: fn for fn in FN}
dnOid2item = {dn['_id']: dn for dn in DN}

fnIdx2item = {i: fn for i, fn in enumerate(FN)}
dnIdx2item = {i: dn for i, dn in enumerate(DN)}

fnOid2idx = {fn['_id']: i for i, fn in enumerate(FN)}
dnOid2idx = {dn['_id']: i for i, dn in enumerate(DN)}

len(FN), len(DN)
# Out:
# (11934, 27505)

# %% [markdown]
# ## Kmeans clutering cases

# %%
with open('./data/Weibo/kmeans.pkl', 'rb') as f:
    kmeans = pickle.load(f)
    
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=20, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=1)

# %%
centers = np.load('./data/Weibo/kmeans_cluster_centers.npy')
centers.shape
# Out:
# (20, 768)

# %%
centers
# Out:
# array([[-6.77433375e-04,  1.15634606e-03, -4.01611179e-03, ...,
#          7.70760106e-03,  7.26240608e-03,  7.32099289e-03],
#        [-5.01510243e-03,  1.07961863e-03, -4.01010013e-03, ...,
#         -1.24469933e-03,  7.92319694e-03, -7.95894576e-03],
#        [ 9.37229458e-04,  3.48859839e-03, -6.49430670e-03, ...,
#          2.98523055e-03, -4.44983851e-03, -2.69852351e-03],
#        ...,
#        [-5.26533446e-04,  5.26453579e-03,  4.87067658e-03, ...,
#         -4.07386656e-03, -8.10667741e-03,  5.22823139e-03],
#        [ 4.73691415e-03,  5.07404897e-03,  2.19203026e-03, ...,
#          7.53568484e-05, -3.14491691e-03,  6.93745064e-03],
#        [-5.34702413e-04,  4.28005703e-04, -5.26110912e-04, ...,
#         -4.80198137e-03, -3.76390257e-03, -1.32672381e-02]])

# %%
y = kmeans.labels_
X = np.load('./data/Weibo/clustering_X.npy')
X.shape, y.shape
# Out:
# ((253547, 768), (253547,))

# %%
dataIdx = pickle.load(open('./data/Weibo/clustering_X_dataIdx.pkl', 'rb'))
len(dataIdx)
# Out:
# 253547

# %%
y
# Out:
# array([ 6,  6, 15, ..., 15,  3, 15], dtype=int32)

# %%
dataIdx
# Out:
# {0: (1, 2245, 1),
#  1: (1, 2245, 5),
#  2: (1, 2245, 6),
#  3: (1, 2245, 11),
#  4: (1, 2245, 12),
#  5: (1, 2245, 16),
#  6: (1, 2245, 17),
#  7: (1, 2245, 19),
#  8: (1, 2245, 20),
#  9: (1, 2245, 21),
#  10: (1, 2245, 24),
#  11: (1, 2245, 26),
#  12: (1, 2245, 30),
#  13: (1, 2245, 31),
#  14: (1, 2245, 33),
#  15: (1, 2245, 36),
#  16: (1, 2245, 39),
#  17: (1, 2245, 43),
#  18: (1, 2245, 44),
#  19: (1, 2245, 45),
#  20: (1, 2245, 46),
#  21: (1, 2245, 47),
#  22: (1, 2245, 48),
#  23: (1, 2245, 49),
#  24: (1, 2245, 51),
#  25: (1, 9901, 2),
#  26: (1, 9901, 6),
#  27: (1, 9901, 8),
#  28: (1, 9901, 15),
#  29: (1, 9901, 16),
#  30: (1, 9901, 19),
#  31: (1, 9901, 20),
#  32: (1, 9901, 22),
#  33: (1, 9901, 23),
#  34: (1, 9901, 31),
#  35: (1, 9901, 40),
#  36: (1, 9901, 41),
#  37: (1, 9901, 48),
#  38: (1, 9901, 52),
#  39: (1, 9901, 54),
#  40: (1, 9901, 56),
#  41: (1, 9901, 59),
#  42: (1, 9901, 60),
#  43: (1, 1343, 1),
#  44: (3, 22, 3),
#  45: (3, 22, 9),
#  46: (3, 22, 10),
#  47: (3, 22, 46),
#  48: (4, 1141, 1),
#  49: (4, 1141, 13),
#  50: (4, 1141, 14),
#  51: (4, 1141, 42),
#  52: (4, 1141, 47),
#  53: (4, 26510, 0),
#  54: (4, 26510, 5),
#  55: (4, 26510, 6),
#  56: (4, 26510, 11),
#  57: (4, 26510, 16),
#  58: (4, 26510, 22),
#  59: (4, 26510, 24),
#  60: (4, 26510, 31),
#  61: (4, 26510, 37),
#  62: (4, 26510, 41),
#  63: (4, 27280, 4),
#  64: (4, 27280, 15),
#  65: (4, 27280, 17),
#  66: (4, 27280, 18),
#  67: (4, 27280, 21),
#  68: (4, 27280, 25),
#  69: (4, 27280, 26),
#  70: (4, 27280, 28),
#  71: (4, 27280, 33),
#  72: (4, 27280, 34),
#  73: (4, 7324, 0),
#  74: (4, 7324, 2),
#  75: (4, 3735, 2),
#  76: (4, 3735, 7),
#  77: (4, 3735, 9),
#  78: (4, 3735, 11),
#  79: (4, 3735, 23),
#  80: (4, 17266, 10),
#  81: (4, 17266, 11),
#  82: (4, 17266, 20),
#  83: (4, 17266, 22),
#  84: (4, 17266, 25),
#  85: (4, 17266, 29),
#  86: (4, 17266, 30),
#  87: (4, 17266, 34),
#  88: (4, 17266, 36),
#  89: (4, 17266, 47),
#  90: (4, 26731, 10),
#  91: (4, 26731, 13),
#  92: (4, 19526, 5),
#  93: (4, 19526, 6),
#  94: (4, 19526, 7),
#  95: (4, 19526, 8),
#  96: (4, 19526, 9),
#  97: (4, 19526, 15),
#  98: (4, 19526, 20),
#  99: (4, 19526, 31),
#  100: (4, 19526, 33),
#  101: (4, 19526, 51),
#  102: (4, 19526, 53),
#  103: (4, 19526, 58),
#  104: (4, 19526, 59),
#  105: (4, 19526, 63),
#  106: (4, 19526, 75),
#  107: (4, 19526, 76),
#  108: (4, 19526, 83),
#  109: (4, 19526, 91),
#  110: (4, 19526, 92),
#  111: (4, 19526, 95),
#  112: (4, 19526, 100),
#  113: (4, 19533, 0),
#  114: (4, 19533, 5),
#  115: (4, 19533, 6),
#  116: (4, 19533, 13),
#  117: (4, 19533, 22),
#  118: (4, 19533, 35),
#  119: (4, 19533, 46),
#  120: (4, 19533, 49),
#  121: (4, 19533, 51),
#  122: (4, 19533, 58),
#  123: (4, 19533, 59),
#  124: (4, 19533, 64),
#  125: (4, 19533, 65),
#  126: (4, 19533, 66),
#  127: (4, 19533, 70),
#  128: (4, 19533, 71),
#  129: (4, 19533, 72),
#  130: (4, 501, 3),
#  131: (4, 26153, 6),
#  132: (4, 26153, 7),
#  133: (4, 26153, 11),
#  134: (4, 26153, 12),
#  135: (4, 26153, 13),
#  136: (4, 26153, 16),
#  137: (4, 26153, 19),
#  138: (4, 26153, 21),
#  139: (4, 26153, 22),
#  140: (4, 26153, 23),
#  141: (4, 26153, 26),
#  142: (4, 26153, 28),
#  143: (4, 26153, 31),
#  144: (4, 26153, 35),
#  145: (4, 18530, 1),
#  146: (4, 18530, 3),
#  147: (4, 18530, 8),
#  148: (4, 18530, 19),
#  149: (4, 7288, 1),
#  150: (4, 7288, 3),
#  151: (4, 7288, 5),
#  152: (4, 18260, 0),
#  153: (4, 18260, 3),
#  154: (4, 18260, 7),
#  155: (4, 16277, 2),
#  156: (4, 14240, 1),
#  157: (4, 16520, 4),
#  158: (4, 16520, 5),
#  159: (4, 16520, 7),
#  160: (4, 16520, 9),
#  161: (4, 3869, 0),
#  162: (4, 3869, 1),
#  163: (4, 3869, 6),
#  164: (4, 3869, 9),
#  165: (4, 3869, 12),
#  166: (4, 3869, 13),
#  167: (4, 3869, 14),
#  168: (4, 3869, 17),
#  169: (4, 3869, 28),
#  170: (4, 3869, 30),
#  171: (4, 3869, 31),
#  172: (4, 3869, 32),
#  173: (4, 3869, 33),
#  174: (4, 18910, 2),
#  175: (4, 18910, 7),
#  176: (4, 18910, 14),
#  177: (4, 18910, 20),
#  178: (4, 18910, 23),
#  179: (4, 18910, 25),
#  180: (4, 18910, 27),
#  181: (4, 17964, 0),
#  182: (4, 17964, 4),
#  183: (4, 17964, 8),
#  184: (4, 17964, 18),
#  185: (4, 17964, 20),
#  186: (4, 17964, 27),
#  187: (4, 17964, 32),
#  188: (4, 17964, 35),
#  189: (4, 17964, 38),
#  190: (4, 17964, 39),
#  191: (4, 17964, 45),
#  192: (4, 17964, 48),
#  193: (4, 17964, 51),
#  194: (4, 17964, 53),
#  195: (4, 17964, 54),
#  196: (4, 17964, 58),
#  197: (4, 17964, 60),
#  198: (4, 17964, 64),
#  199: (4, 17964, 67),
#  200: (4, 17964, 75),
#  201: (4, 17964, 82),
#  202: (4, 17964, 84),
#  203: (4, 17964, 85),
#  204: (4, 17964, 86),
#  205: (4, 17964, 88),
#  206: (4, 17964, 89),
#  207: (4, 17964, 90),
#  208: (4, 17964, 93),
#  209: (4, 17964, 96),
#  210: (4, 12830, 2),
#  211: (4, 9963, 5),
#  212: (4, 9963, 10),
#  213: (4, 9963, 12),
#  214: (4, 9963, 13),
#  215: (4, 9963, 14),
#  216: (4, 9963, 16),
#  217: (4, 9963, 25),
#  218: (4, 9963, 37),
#  219: (4, 9598, 11),
#  220: (4, 9598, 23),
#  221: (4, 9598, 29),
#  222: (4, 16302, 1),
#  223: (4, 16302, 13),
#  224: (6, 2245, 1),
#  225: (6, 2245, 6),
#  226: (6, 2245, 8),
#  227: (6, 2245, 14),
#  228: (6, 2245, 15),
#  229: (6, 2245, 17),
#  543: (9, 26731, 8),
#  544: (9, 26731, 10),
#  545: (9, 26731, 13),
#  546: (9, 26731, 22),
#  547: (9, 26731, 25),
#  548: (9, 26731, 26),
#  549: (9, 19526, 4),
#  550: (9, 19526, 5),
#  551: (9, 19526, 6),
#  552: (9, 19526, 8),
#  553: (9, 19526, 9),
#  554: (9, 19526, 15),
#  555: (9, 19526, 17),
#  556: (9, 19526, 20),
#  557: (9, 19526, 31),
#  558: (9, 19526, 33),
#  559: (9, 19526, 38),
#  560: (9, 19526, 49),
#  561: (9, 19526, 51),
#  562: (9, 19526, 58),
#  563: (9, 19526, 59),
#  564: (9, 19526, 63),
#  565: (9, 19526, 71),
#  566: (9, 19526, 75),
#  567: (9, 19526, 88),
#  568: (9, 19526, 91),
#  569: (9, 19526, 92),
#  570: (9, 19526, 98),
#  571: (9, 19526, 99),
#  572: (9, 19526, 100),
#  573: (9, 483, 2),
#  574: (9, 19533, 0),
#  575: (9, 19533, 6),
#  576: (9, 19533, 13),
#  577: (9, 19533, 17),
#  578: (9, 19533, 19),
#  579: (9, 19533, 22),
#  580: (9, 19533, 33),
#  581: (9, 19533, 35),
#  582: (9, 19533, 36),
#  583: (9, 19533, 40),
#  584: (9, 19533, 46),
#  585: (9, 19533, 49),
#  586: (9, 19533, 51),
#  587: (9, 19533, 58),
#  588: (9, 19533, 59),
#  589: (9, 19533, 63),
#  590: (9, 19533, 64),
#  591: (9, 19533, 65),
#  592: (9, 19533, 66),
#  593: (9, 19533, 70),
#  594: (9, 19533, 71),
#  595: (9, 501, 3),
#  596: (9, 26153, 5),
#  597: (9, 26153, 6),
#  598: (9, 26153, 7),
#  599: (9, 26153, 13),
#  600: (9, 26153, 16),
#  601: (9, 26153, 18),
#  602: (9, 26153, 19),
#  603: (9, 26153, 21),
#  604: (9, 26153, 23),
#  605: (9, 26153, 26),
#  606: (9, 26153, 28),
#  607: (9, 26153, 29),
#  608: (9, 26153, 31),
#  609: (9, 26153, 39),
#  610: (9, 18530, 1),
#  611: (9, 18530, 3),
#  612: (9, 18530, 6),
#  613: (9, 18530, 8),
#  614: (9, 18530, 19),
#  615: (9, 7288, 4),
#  616: (9, 7288, 5),
#  617: (9, 18260, 0),
#  618: (9, 18260, 3),
#  619: (9, 18260, 6),
#  620: (9, 18260, 7),
#  621: (9, 16277, 2),
#  622: (9, 14240, 1),
#  623: (9, 16520, 4),
#  624: (9, 16520, 5),
#  625: (9, 16520, 7),
#  626: (9, 3869, 0),
#  627: (9, 3869, 1),
#  628: (9, 3869, 6),
#  629: (9, 3869, 9),
#  630: (9, 3869, 13),
#  631: (9, 3869, 14),
#  632: (9, 3869, 16),
#  633: (9, 3869, 22),
#  634: (9, 3869, 27),
#  635: (9, 3869, 28),
#  636: (9, 3869, 30),
#  637: (9, 3869, 31),
#  638: (9, 3869, 32),
#  639: (9, 3869, 33),
#  640: (9, 3869, 38),
#  641: (9, 18910, 2),
#  642: (9, 18910, 7),
#  643: (9, 18910, 14),
#  644: (9, 18910, 20),
#  645: (9, 18910, 23),
#  646: (9, 18910, 25),
#  647: (9, 17964, 0),
#  648: (9, 17964, 4),
#  649: (9, 17964, 18),
#  650: (9, 17964, 20),
#  651: (9, 17964, 21),
#  652: (9, 17964, 25),
#  653: (9, 17964, 27),
#  654: (9, 17964, 35),
#  655: (9, 17964, 39),
#  656: (9, 17964, 41),
#  657: (9, 17964, 42),
#  658: (9, 17964, 45),
#  659: (9, 17964, 48),
#  660: (9, 17964, 51),
#  661: (9, 17964, 53),
#  662: (9, 17964, 54),
#  663: (9, 17964, 56),
#  664: (9, 17964, 58),
#  665: (9, 17964, 67),
#  666: (9, 17964, 75),
#  667: (9, 17964, 82),
#  668: (9, 17964, 84),
#  669: (9, 17964, 85),
#  670: (9, 17964, 86),
#  671: (9, 17964, 88),
#  672: (9, 17964, 89),
#  673: (9, 17964, 90),
#  674: (9, 17964, 93),
#  675: (9, 17964, 94),
#  676: (9, 12830, 3),
#  677: (9, 12962, 3),
#  678: (9, 9963, 5),
#  679: (9, 9963, 12),
#  680: (9, 9963, 13),
#  681: (9, 9963, 16),
#  682: (9, 9963, 21),
#  683: (9, 9963, 24),
#  684: (9, 9963, 25),
#  685: (9, 9963, 37),
#  686: (9, 9598, 11),
#  687: (9, 9598, 23),
#  688: (9, 9598, 29),
#  689: (9, 16302, 1),
#  690: (9, 16302, 13),
#  691: (10, 1141, 1),
#  692: (10, 1141, 13),
#  693: (10, 1141, 33),
#  694: (10, 1141, 47),
#  695: (10, 26510, 0),
#  696: (10, 26510, 5),
#  697: (10, 26510, 6),
#  698: (10, 26510, 7),
#  699: (10, 26510, 11),
#  700: (10, 26510, 16),
#  701: (10, 26510, 24),
#  702: (10, 26510, 31),
#  703: (10, 26510, 32),
#  704: (10, 26510, 39),
#  705: (10, 27280, 15),
#  706: (10, 27280, 17),
#  707: (10, 27280, 21),
#  708: (10, 27280, 26),
#  709: (10, 27280, 28),
#  710: (10, 27280, 34),
#  711: (10, 7324, 2),
#  712: (10, 3735, 2),
#  713: (10, 3735, 7),
#  714: (10, 3735, 9),
#  715: (10, 3735, 11),
#  716: (10, 3735, 15),
#  717: (10, 3735, 17),
#  718: (10, 17266, 4),
#  719: (10, 17266, 5),
#  720: (10, 17266, 8),
#  721: (10, 17266, 10),
#  722: (10, 17266, 17),
#  723: (10, 17266, 20),
#  724: (10, 17266, 24),
#  725: (10, 17266, 25),
#  726: (10, 17266, 29),
#  727: (10, 17266, 33),
#  728: (10, 17266, 36),
#  729: (10, 17266, 45),
#  730: (10, 17266, 46),
#  731: (10, 17266, 47),
#  732: (10, 26731, 0),
#  733: (10, 26731, 10),
#  734: (10, 26731, 13),
#  735: (10, 26731, 16),
#  736: (10, 19526, 5),
#  737: (10, 19526, 6),
#  738: (10, 19526, 7),
#  739: (10, 19526, 15),
#  740: (10, 19526, 17),
#  741: (10, 19526, 20),
#  742: (10, 19526, 31),
#  743: (10, 19526, 42),
#  744: (10, 19526, 47),
#  745: (10, 19526, 50),
#  746: (10, 19526, 51),
#  747: (10, 19526, 53),
#  748: (10, 19526, 58),
#  852: (11, 26510, 6),
#  853: (11, 26510, 10),
#  854: (11, 26510, 16),
#  855: (11, 26510, 22),
#  856: (11, 26510, 24),
#  857: (11, 26510, 31),
#  858: (11, 26510, 41),
#  859: (11, 27280, 4),
#  860: (11, 27280, 18),
#  861: (11, 27280, 21),
#  862: (11, 27280, 25),
#  863: (11, 27280, 26),
#  864: (11, 27280, 28),
#  865: (11, 27280, 34),
#  866: (11, 7324, 2),
#  867: (11, 3735, 7),
#  868: (11, 3735, 9),
#  869: (11, 3735, 10),
#  870: (11, 3735, 11),
#  871: (11, 3735, 15),
#  872: (11, 3735, 22),
#  873: (11, 17266, 10),
#  874: (11, 17266, 11),
#  875: (11, 17266, 20),
#  876: (11, 17266, 25),
#  877: (11, 17266, 33),
#  878: (11, 17266, 34),
#  879: (11, 17266, 47),
#  880: (11, 26731, 10),
#  881: (11, 26731, 13),
#  882: (11, 19526, 5),
#  883: (11, 19526, 6),
#  884: (11, 19526, 8),
#  885: (11, 19526, 9),
#  886: (11, 19526, 15),
#  887: (11, 19526, 20),
#  888: (11, 19526, 31),
#  889: (11, 19526, 42),
#  890: (11, 19526, 49),
#  891: (11, 19526, 51),
#  892: (11, 19526, 58),
#  893: (11, 19526, 59),
#  894: (11, 19526, 61),
#  895: (11, 19526, 63),
#  896: (11, 19526, 75),
#  897: (11, 19526, 76),
#  898: (11, 19526, 91),
#  899: (11, 19526, 92),
#  900: (11, 19526, 100),
#  901: (11, 19533, 5),
#  902: (11, 19533, 22),
#  903: (11, 19533, 46),
#  904: (11, 19533, 50),
#  905: (11, 19533, 51),
#  906: (11, 19533, 58),
#  907: (11, 19533, 59),
#  908: (11, 19533, 64),
#  909: (11, 19533, 71),
#  910: (11, 19533, 72),
#  911: (11, 501, 3),
#  912: (11, 26153, 6),
#  913: (11, 26153, 13),
#  914: (11, 26153, 16),
#  915: (11, 26153, 19),
#  916: (11, 26153, 21),
#  917: (11, 26153, 23),
#  918: (11, 26153, 26),
#  919: (11, 26153, 28),
#  920: (11, 26153, 31),
#  921: (11, 26153, 35),
#  922: (11, 26153, 39),
#  923: (11, 26153, 44),
#  924: (11, 18530, 1),
#  925: (11, 18530, 3),
#  926: (11, 18530, 8),
#  927: (11, 18530, 19),
#  928: (11, 7288, 1),
#  929: (11, 18260, 0),
#  930: (11, 18260, 3),
#  931: (11, 18260, 7),
#  932: (11, 16277, 2),
#  933: (11, 14240, 1),
#  934: (11, 16520, 4),
#  935: (11, 16520, 5),
#  936: (11, 3869, 0),
#  937: (11, 3869, 1),
#  938: (11, 3869, 6),
#  939: (11, 3869, 12),
#  940: (11, 3869, 13),
#  941: (11, 3869, 14),
#  942: (11, 3869, 17),
#  943: (11, 3869, 28),
#  944: (11, 3869, 30),
#  945: (11, 3869, 31),
#  946: (11, 3869, 32),
#  947: (11, 3869, 33),
#  948: (11, 3869, 34),
#  949: (11, 18910, 2),
#  950: (11, 18910, 7),
#  951: (11, 18910, 14),
#  952: (11, 18910, 16),
#  953: (11, 18910, 20),
#  954: (11, 18910, 23),
#  955: (11, 18910, 25),
#  956: (11, 17964, 18),
#  957: (11, 17964, 20),
#  958: (11, 17964, 24),
#  959: (11, 17964, 25),
#  960: (11, 17964, 27),
#  961: (11, 17964, 32),
#  962: (11, 17964, 35),
#  963: (11, 17964, 45),
#  964: (11, 17964, 48),
#  965: (11, 17964, 53),
#  966: (11, 17964, 58),
#  967: (11, 17964, 60),
#  968: (11, 17964, 64),
#  969: (11, 17964, 67),
#  970: (11, 17964, 71),
#  971: (11, 17964, 75),
#  972: (11, 17964, 77),
#  973: (11, 17964, 78),
#  974: (11, 17964, 82),
#  975: (11, 17964, 84),
#  976: (11, 17964, 85),
#  977: (11, 17964, 86),
#  978: (11, 17964, 88),
#  979: (11, 17964, 89),
#  980: (11, 17964, 93),
#  981: (11, 17964, 96),
#  982: (11, 12830, 2),
#  983: (11, 12830, 3),
#  984: (11, 12962, 3),
#  985: (11, 9963, 5),
#  986: (11, 9963, 10),
#  987: (11, 9963, 12),
#  988: (11, 9963, 13),
#  989: (11, 9963, 16),
#  990: (11, 9963, 25),
#  991: (11, 9963, 37),
#  992: (11, 9598, 23),
#  993: (11, 9598, 29),
#  994: (11, 16302, 13),
#  995: (11, 16302, 16),
#  996: (13, 1141, 14),
#  997: (13, 26510, 0),
#  998: (13, 26510, 5),
#  999: (13, 26510, 10),
#  ...}

# %%
np.where(y==0)
# Out:
# (array([    27,     28,     73, ..., 253529, 253530, 253543]),)

# %%
SHOW = 50

# C = random.randint(0, 19)
# C = 0

samples = np.where(y == C)[0].tolist()
print('C = {}, samples = {} ({:.3%})\n'.format(
    C, len(samples), len(samples)/len(y)))
print('-'*25)

for cidx in samples[:SHOW]:
    qidx, didx, sidx = dataIdx[cidx]
    print('[qidx={}, didx={}, sidx={}]\t{}'.format(
        qidx, didx, sidx, DN[didx]['content_all'][sidx]))

print('\n', '-'*25, '\n')

for cidx in random.sample(samples, min(SHOW, len(samples))):
    qidx, didx, sidx = dataIdx[cidx]
    print('[qidx={}, didx={}, sidx={}]\t{}'.format(
        qidx, didx, sidx, DN[didx]['content_all'][sidx]))

C += 1
# Out:
# C = 3, samples = 14756 (5.820%)
#
# -------------------------
# [qidx=1, didx=9901, sidx=19]	是不是肉鸡产业中的潜规则？”
# [qidx=4, didx=26510, sidx=22]	➋小龙虾是日本人的阴谋？
# [qidx=4, didx=26510, sidx=31]	➍小龙虾爱脏水，重金属很多？
# [qidx=4, didx=17266, sidx=25]	那小龙虾最爱“污水”的传说又是真的吗？
# [qidx=4, didx=26731, sidx=10]	而诸多以前出现过的说法更是“老生常谈”。
# [qidx=4, didx=19526, sidx=76]	网上也有种说法，认为是“洗虾粉”导致了横纹肌溶解症。
# [qidx=4, didx=19533, sidx=22]	美国FDA的毒素检测也没发现致病物质，只能用“哈夫病”结案。
# [qidx=4, didx=26153, sidx=22]	 为了适应污染的环境，克氏原螯虾有一套独家排毒机制——蜕壳。
# [qidx=4, didx=7288, sidx=1]	[吃瓜]】在#世界杯# “标配”——“小龙虾+啤酒”被热捧之时，一则号称“吃小龙虾会导致哈夫病和肺吸虫病”“小龙虾致命”“全世界都不敢吃”“中国人蒙在鼓里”的消息又火了。
# [qidx=4, didx=17964, sidx=35]	肺吸虫是一个特别会“抱大腿”的主儿。
# [qidx=4, didx=17964, sidx=64]	食用小龙虾后出现的横纹肌溶解症，称之为Haff病。
# [qidx=4, didx=9963, sidx=10]	小龙虾的真名叫“克氏原螯虾”，学名叫Procambarus clarkii，是一种如假包换的淡水虾。
# [qidx=7, didx=49, sidx=18]	也因此，2010年微博造假“异军突起”，如影响恶劣的“金庸被去世”、“鲁迅作品大撤退”等假新闻都来源于微博。
# [qidx=7, didx=49, sidx=259]	“年度假新闻”评选引起主管部门的高度重视。
# [qidx=7, didx=49, sidx=270]	尽管“假”始终与“真”相伴，且虚假新闻报道成因复杂，所以无数新闻报道中夹杂着若干“客里空”也不足为奇。
# [qidx=7, didx=49, sidx=303]	为什么至今尚未对造假责任者实行“零容忍”、“零宽恕”，以致常常无人为造假担责？
# [qidx=8, didx=17266, sidx=25]	那小龙虾最爱“污水”的传说又是真的吗？
# [qidx=8, didx=26731, sidx=10]	而诸多以前出现过的说法更是“老生常谈”。
# [qidx=8, didx=19526, sidx=76]	网上也有种说法，认为是“洗虾粉”导致了横纹肌溶解症。
# [qidx=8, didx=19533, sidx=22]	美国FDA的毒素检测也没发现致病物质，只能用“哈夫病”结案。
# [qidx=8, didx=7288, sidx=1]	[吃瓜]】在#世界杯# “标配”——“小龙虾+啤酒”被热捧之时，一则号称“吃小龙虾会导致哈夫病和肺吸虫病”“小龙虾致命”“全世界都不敢吃”“中国人蒙在鼓里”的消息又火了。
# [qidx=8, didx=17964, sidx=35]	肺吸虫是一个特别会“抱大腿”的主儿。
# [qidx=8, didx=17964, sidx=75]	目前认为，Haff病可能跟某种目前尚未检测出的毒素有关。
# [qidx=9, didx=26510, sidx=22]	➋小龙虾是日本人的阴谋？
# [qidx=9, didx=26510, sidx=31]	➍小龙虾爱脏水，重金属很多？
# [qidx=9, didx=3735, sidx=10]	有网友评论视频发布者“缺乏生活经验”，转发者“也不弄清事实就疯转”，还有网友认为“总觉得是有组织的造谣传播者”，“应对造谣者进行处理”。
# [qidx=9, didx=17266, sidx=25]	那小龙虾最爱“污水”的传说又是真的吗？
# [qidx=9, didx=19533, sidx=22]	美国FDA的毒素检测也没发现致病物质，只能用“哈夫病”结案。
# [qidx=9, didx=18530, sidx=6]	文章称“小龙虾会导致哈夫病”“外国人现在都不吃了，在中国却火热起来……”等等。
# [qidx=9, didx=17964, sidx=18]	小龙虾“招惹”的细菌，主要有致病性弧菌和金黄色葡萄球菌两类。
# [qidx=9, didx=17964, sidx=35]	肺吸虫是一个特别会“抱大腿”的主儿。
# [qidx=10, didx=19526, sidx=76]	网上也有种说法，认为是“洗虾粉”导致了横纹肌溶解症。
# [qidx=10, didx=7288, sidx=1]	[吃瓜]】在#世界杯# “标配”——“小龙虾+啤酒”被热捧之时，一则号称“吃小龙虾会导致哈夫病和肺吸虫病”“小龙虾致命”“全世界都不敢吃”“中国人蒙在鼓里”的消息又火了。
# [qidx=10, didx=17964, sidx=35]	肺吸虫是一个特别会“抱大腿”的主儿。
# [qidx=10, didx=17964, sidx=67]	患者都食用了水产品，如淡水鲳鱼、三文鱼等；
# [qidx=11, didx=26510, sidx=22]	➋小龙虾是日本人的阴谋？
# [qidx=11, didx=3735, sidx=10]	有网友评论视频发布者“缺乏生活经验”，转发者“也不弄清事实就疯转”，还有网友认为“总觉得是有组织的造谣传播者”，“应对造谣者进行处理”。
# [qidx=11, didx=17266, sidx=25]	那小龙虾最爱“污水”的传说又是真的吗？
# [qidx=11, didx=26731, sidx=10]	而诸多以前出现过的说法更是“老生常谈”。
# [qidx=11, didx=19526, sidx=76]	网上也有种说法，认为是“洗虾粉”导致了横纹肌溶解症。
# [qidx=11, didx=19533, sidx=22]	美国FDA的毒素检测也没发现致病物质，只能用“哈夫病”结案。
# [qidx=11, didx=7288, sidx=1]	[吃瓜]】在#世界杯# “标配”——“小龙虾+啤酒”被热捧之时，一则号称“吃小龙虾会导致哈夫病和肺吸虫病”“小龙虾致命”“全世界都不敢吃”“中国人蒙在鼓里”的消息又火了。
# [qidx=11, didx=17964, sidx=35]	肺吸虫是一个特别会“抱大腿”的主儿。
# [qidx=11, didx=17964, sidx=64]	食用小龙虾后出现的横纹肌溶解症，称之为Haff病。
# [qidx=11, didx=17964, sidx=67]	患者都食用了水产品，如淡水鲳鱼、三文鱼等；
# [qidx=11, didx=17964, sidx=75]	目前认为，Haff病可能跟某种目前尚未检测出的毒素有关。
# [qidx=13, didx=26510, sidx=22]	➋小龙虾是日本人的阴谋？
# [qidx=13, didx=17266, sidx=25]	那小龙虾最爱“污水”的传说又是真的吗？
# [qidx=13, didx=26731, sidx=10]	而诸多以前出现过的说法更是“老生常谈”。
# [qidx=13, didx=19526, sidx=4]	它们之间的亲缘关系相当于人和猴子的关系，都是一个“目”，但不是一个“科”。
#
#  -------------------------
#
# [qidx=8306, didx=6929, sidx=4]	随后新西兰跳伞公司回应：“安全绳在脚下！”
# [qidx=6351, didx=3542, sidx=13]	证明“塑料大米”是谣言的证据有以下三点：
# [qidx=6812, didx=12674, sidx=1]	经查，该微博称“挂面泡出胶”不实。
# [qidx=6710, didx=12914, sidx=4]	经查，该微博称“视频里被打的人就是赵鑫”不实。
# [qidx=6842, didx=14440, sidx=0]	原标题：2018十大“科学”流言榜揭晓 “酸性体质是百病之源”位列榜首 今天（1月10日），2018年度十大“科学”流言求真榜在北京科学中心揭晓，“酸性体质是百病之源”位列十大“科学”流言榜之首。
# [qidx=608, didx=19298, sidx=9]	募捐信息写到，“我是甘肃的一位老师，叫格桑加。
# [qidx=9990, didx=16952, sidx=2]	在这张发布者声称在非洲看到的广告牌上，可以看到“性侵、性侵、性侵，你可以在中国做这样的事，将不会受到惩罚……”等内容。
# [qidx=10347, didx=20492, sidx=5]	为什么中文称“荷兰”而非“尼德兰”？
# [qidx=3236, didx=16810, sidx=93]	提醒中老年网友，避免掉入这些“作文秀”的陷阱中，误导青少年教育。
# [qidx=9474, didx=15187, sidx=4]	虽然，“国际警察日”是假节日，但不影响我们向警察蜀黍致敬！
# [qidx=3326, didx=2177, sidx=16]	“希望沈阳晚报能及时澄清，别让市民被不实消息误导。”
# [qidx=6304, didx=3542, sidx=33]	“XX视频是塑料做的”已成为造谣者的一个套路。
# [qidx=8513, didx=7685, sidx=0]	“程序员和产品经理打架”官方回应：个人矛盾。
# [qidx=6949, didx=12813, sidx=5]	经查，该微博称“肉松棉花做的”不实。
# [qidx=1655, didx=119, sidx=0]	“西瓜新品种你吃过了吗” “蓝瓤西瓜”现身海南？
# [qidx=10143, didx=14081, sidx=0]	发布了头条文章：《“不是”：赵薇亲自澄清新加坡国籍？
# [qidx=2436, didx=8956, sidx=22]	他表示：“网上流传的消息不实，马航MH370没有在柬埔寨坠落”。
# [qidx=6776, didx=12774, sidx=3]	经查，该微博称“四川省泸州市一学生被活活打死”不实。
# [qidx=11807, didx=506, sidx=2]	不少人看后纷纷感慨：“一下子年轻了10岁，感谢联合国帮我们找回青春。”
# [qidx=3506, didx=440, sidx=20]	后来它又在2010年的玉树地震中救了32人，又“牺牲”了。
# [qidx=1342, didx=440, sidx=10]	此号码还曾出现在《“微博爱心接力”原是大忽悠王均豪任志强随手@推波助澜》。
# [qidx=7847, didx=26510, sidx=22]	➋小龙虾是日本人的阴谋？
# [qidx=452, didx=16985, sidx=37]	令人啼笑皆非的是，最新冒出来的“热苦瓜水能治疗癌症”的帖子，还只是简单把“柠檬（鸭梨）”换成了“苦瓜”。
# [qidx=370, didx=94, sidx=6]	上述负责人表示，“根本不存在迟到一说。”
# [qidx=10136, didx=4021, sidx=3]	“别再吃了，肉松蛋糕都是棉花做的！”
# [qidx=10724, didx=14708, sidx=80]	自媒体领域不是“法外之地”早已成为共识，谣言止于智者，更止于“治者”。
# [qidx=11093, didx=23911, sidx=27]	Mattia从何处感染新冠病毒目前仍是谜团。
# [qidx=4946, didx=19258, sidx=3]	在大家都互相关心应该穿暖时朋友圈内一则“甘肃老师‘格桑加’为贫困孩子募集衣物”的信息引起了很多爱心人士的关注。
# [qidx=5540, didx=1916, sidx=3]	香山公园管理处日前也表示，“香山公园有古王府出售”属于虚假信息。
# [qidx=7716, didx=8873, sidx=12]	 17日凌晨，“菩萨祈福图”的原作者“正月插画师”，微博认证为“插画师、美术教师”，发布消息称“我这画似乎火了，火的十分突然。
# [qidx=7129, didx=6156, sidx=14]	“人的大脑和一台电脑的工作原理本质上差不多。
# [qidx=9720, didx=14440, sidx=0]	原标题：2018十大“科学”流言榜揭晓 “酸性体质是百病之源”位列榜首 今天（1月10日），2018年度十大“科学”流言求真榜在北京科学中心揭晓，“酸性体质是百病之源”位列十大“科学”流言榜之首。
# [qidx=7975, didx=13006, sidx=2]	经查，此微博发视频称“#空姐滴滴打车遇害#凶手被抓了。”
# [qidx=10239, didx=19113, sidx=27]	视频长约4分钟，视频上还写有“中国古典舞”的字样。
# [qidx=6135, didx=8969, sidx=8]	那么，这份网传“新交规”都有哪些不实之处？
# [qidx=6382, didx=18223, sidx=14]	视频套路大抵相同：首先水洗肉松，紧接着发现肉松竟是“棉花”做的，继而斥责肉松糕点商家。
# [qidx=10207, didx=9340, sidx=3]	还有网友称，“这家人是广东省英德市石灰铺镇的。”
# [qidx=6342, didx=11045, sidx=15]	 而在另一则“棉花肉松”的谣言中，“本地化”的表现不再仅限于变换地名，还引发了多地居民的模仿和实验。
# [qidx=13, didx=17964, sidx=64]	食用小龙虾后出现的横纹肌溶解症，称之为Haff病。
# [qidx=6323, didx=3112, sidx=1]	继“塑料大米”、“塑料紫菜”的谣言视频在网上热传后，一段“火烧塑料粉丝”的视频这几天又在网上流传。
# [qidx=8928, didx=10179, sidx=6]	“甘A⋅80000—甘A⋅89999”纯数字号段为公安交警部门为兰州市出租车设置的专用号段。
# [qidx=6391, didx=3542, sidx=13]	证明“塑料大米”是谣言的证据有以下三点：
# [qidx=6814, didx=3371, sidx=6]	­最近有关食品的视频总是在“朋友圈”里热转。
# [qidx=289, didx=16985, sidx=5]	“热柠檬水抗癌治癌说”传了好多年
# [qidx=3381, didx=932, sidx=9]	丝状蚴的体长就更短了，连 1 毫米都不到。
# [qidx=7199, didx=2963, sidx=1]	该消息称，“此次行动共计1200个酒驾任务”。
# [qidx=9341, didx=7587, sidx=3]	更多详情来“科学加”看吧，点这里网页链接（也可在苹果App Store、安卓各应用商店搜索“科学加”下载使用） URL
# [qidx=1546, didx=455, sidx=1]	和类似的信息相同，最后标注着“是中国人转起”等字样。
# [qidx=1800, didx=7288, sidx=1]	[吃瓜]】在#世界杯# “标配”——“小龙虾+啤酒”被热捧之时，一则号称“吃小龙虾会导致哈夫病和肺吸虫病”“小龙虾致命”“全世界都不敢吃”“中国人蒙在鼓里”的消息又火了。
# [qidx=2408, didx=735, sidx=0]	【网传“MH370航班被菲律宾海事船发现”，假消息！

# %% [markdown]
# # Key Sentence Selection (when initialization)

# %%
import torch
from tqdm import tqdm
import json
import random
import numpy as np

# %%
def print_in_color(s, cint=31, end='\n'):
    print('\x1b[{}m{}\x1b[0m'.format(cint, s), end=end)

# %%
with open('../../dataset/Weibo/raw/FN_11934_filtered.json', 'r') as f:
    FN = json.load(f)

with open('../../dataset/Weibo/raw/DN_27505_filtered.json', 'r') as f:
    DN = json.load(f)

fnOid2item = {fn['_id']: fn for fn in FN}
dnOid2item = {dn['_id']: dn for dn in DN}

fnIdx2item = {i: fn for i, fn in enumerate(FN)}
dnIdx2item = {i: dn for i, dn in enumerate(DN)}

fnOid2idx = {fn['_id']: i for i, fn in enumerate(FN)}
dnOid2idx = {dn['_id']: i for i, dn in enumerate(DN)}

len(FN), len(DN)
# Out:
# (11934, 27505)

# %%
fn_embeddings = torch.load(
    '../ROT/data/Weibo/FN_bert-base-chinese_embeddings_static.pt')
dn_embeddings = torch.load(
    '../ROT/data/Weibo/DN_bert-base-chinese_embeddings_static.pt')

len(fn_embeddings), len(dn_embeddings)
# Out:
# (11934, 27505)

# %%
fn_embeddings[0].shape
# Out:
# torch.Size([768])

# %%
memory = np.load('./data/Weibo/kmeans_cluster_centers.npy')
memory.shape
# Out:
# (20, 768)

# %%
def pytorch_euclidean_distance(a, b):
    return torch.dist(a, b).item()

# %%
def get_claim_sentence_scores(fn_emb=fn_embeddings, dn_emb=dn_embeddings):
    score_dict = dict()

    for qidx, fn in enumerate(tqdm(FN)):
        dn_oids = fn['debunking_ids']

        for did in dn_oids:
            dn = dnOid2item[did]
            didx = dnOid2idx[did]

            query = fn_emb[qidx]
            sentences = dn_emb[didx]

            items = [pytorch_euclidean_distance(
                query, sent) for sent in sentences]

            # Scale
            m, M = min(items), max(items)
            items = [1 - (x - m) / (M - m + 1e-8) for x in items]

            if qidx not in score_dict.keys():
                score_dict[qidx] = {didx: items}
            else:
                score_dict[qidx][didx] = items

    return score_dict

# %%
def get_pattern_sentence_scores(fn_emb=fn_embeddings, dn_emb=dn_embeddings):
    score_dict = dict()

    for qidx, fn in enumerate(tqdm(FN)):
        dn_oids = fn['debunking_ids']

        for did in dn_oids:
            dn = dnOid2item[did]
            didx = dnOid2idx[did]

            Q = fn_emb[qidx]
            sentences = dn_emb[didx]

            items = []
            for S in sentences:
                distances = torch.norm((S - Q) - memory, p=2, dim=1)
                center_idx = torch.argmin(distances).item()
                items.append(distances[center_idx].item())

            # Scale
            m, M = min(items), max(items)
            items = [1 - (x - m) / (M - m + 1e-8) for x in items]

            if qidx not in score_dict.keys():
                score_dict[qidx] = {didx: items}
            else:
                score_dict[qidx][didx] = items

    return score_dict

# %%
claim_scores = get_claim_sentence_scores()
# Out:
# 100%|██████████| 11934/11934 [00:45<00:00, 264.56it/s]

# %%
pattern_scores = get_pattern_sentence_scores()
# Out:
# 100%|██████████| 11934/11934 [02:41<00:00, 74.02it/s]

# %%
lmd_Q = 0.6
lmd_P = 0.4

scores = dict()

for qidx in tqdm(claim_scores):
    for didx, Q_scores in claim_scores[qidx].items():
        P_scores = pattern_scores[qidx][didx]
        res_scores = [lmd_Q * Q_scores[i] + lmd_P * P_scores[i]
                      for i in range(len(Q_scores))]

        if qidx not in scores.keys():
            scores[qidx] = {didx: res_scores}
        else:
            scores[qidx][didx] = res_scores
# Out:
# 100%|██████████| 11934/11934 [00:15<00:00, 777.66it/s]

# %%
TOP = 3

qidx = random.randint(0, len(FN) - 1)
fn = FN[qidx]

print('[Fake News]\n{}'.format(fn['content_all']))

for did in fn['debunking_ids']:
    didx = dnOid2idx[did]
    dn = DN[didx]

    s_claim = claim_scores[qidx][didx]
    s_pattern = pattern_scores[qidx][didx]
    s_selection = scores[qidx][didx]

    top_s_claim = sorted(s_claim, reverse=True)[:TOP]
    top_s_pattern = sorted(s_pattern, reverse=True)[:TOP]
    top_s_selection = sorted(s_selection, reverse=True)[:TOP]

    print('\n---------------------------------------------')
    print('qidx = {}, didx = {}\n'.format(qidx, didx))

    print('[Debunking News]')
    for j, sent in enumerate(dn['content_all']):
        print('[Sent-{}]['.format(j), end='')

        print_func = print_in_color if s_claim[j] in top_s_claim else print
        print_func('Claim: {:.3f}'.format(s_claim[j]), end='')

        print(', ', end='')

        print_func = print_in_color if s_pattern[j] in top_s_pattern else print
        print_func('Pattern: {:.3f}'.format(s_pattern[j]), end='')

        print(', ', end='')
        
        print_func = print_in_color if s_selection[j] in top_s_selection else print
        print_func('Result: {:.3f}'.format(s_selection[j]), end='')
        
        print_func(']\t{}'.format(sent))
# Out:
# [Fake News]
# 周萌萌，女，6岁半，于2011年1月31日，在四川省彭州市被拐，已报案。其母亲因思念过度住院，希望借助网络的力量寻求帮助，如网友有线索，请联系萌萌爸爸13962672031。
#
# ---------------------------------------------
# qidx = 278, didx = 14754
#
# [Debunking News]
# [Sent-0][Claim: 0.741, Pattern: 0.765, Result: 0.751]	#平安守护# 【辟谣：锦绣花园一个小孩被拐走！
# [Sent-1][Claim: 1.000, Pattern: 1.000, Result: 1.000]	假的】 近日，鄢陵的朋友圈有人在传一则“十万火急”的寻人信息，信息大致内容是这样的：寻人启事13940292999，有线索酬金10万帮忙扩散，今天上午一个三岁多小女孩在锦绣花园小区附近被人拐走了，从监控中看是被一个四十多岁男人抱走了，现大人都急疯了。
# [Sent-2][Claim: 0.849, Pattern: 0.931, Result: 0.882]	 经小编向相关部门核实，我局并未接到这一警情，这是一则假消息，网络谣言，谣言！
# [Sent-3][Claim: 0.000, Pattern: 0.000, Result: 0.000]	谣言！
# [Sent-4][Claim: 0.806, Pattern: 0.888, Result: 0.839]	当家长的心情都是一样的，可以理解，但是也请学会辨别，免得好心变坏事咯！
# [Sent-5][Claim: 0.300, Pattern: 0.308, Result: 0.303]	 不信谣！
# [Sent-6][Claim: 0.235, Pattern: 0.245, Result: 0.239]	不传谣！
#
# ---------------------------------------------
# qidx = 278, didx = 16094
#
# [Debunking News]
# [Sent-0][Claim: 0.662, Pattern: 0.691, Result: 0.674]	#咸宁身边事#【“重金酬谢，5岁儿子在咸宁双语幼儿园被人拐走！”
# [Sent-1][Claim: 0.127, Pattern: 0.209, Result: 0.160]	这是谣言你别信！
# [Sent-2][Claim: 1.000, Pattern: 1.000, Result: 1.000]	[吃惊]】近日，咸宁微信群又出现谣言了，该谣言乍一看是条求助信息：求转，帮帮忙吧，本人何伟在新农贸做龙虾，电话：13972170176，今天上午的5岁儿子在双语幼儿园附近被人拐走了……
# [Sent-3][Claim: 0.677, Pattern: 0.651, Result: 0.666]	必有重谢 20万元整 谁的群多大家帮忙转发一下！
# [Sent-4][Claim: 0.164, Pattern: 0.185, Result: 0.172]	好 人一生平安。
# [Sent-5][Claim: 0.209, Pattern: 0.361, Result: 0.270]	经核实，该信息为不实信息。
# [Sent-6][Claim: 0.762, Pattern: 0.802, Result: 0.778]	民警巡查搜索发现，每次都只是“丢儿子”的人一直在变，电话号码也跟着换。
# [Sent-7][Claim: 0.559, Pattern: 0.640, Result: 0.591]	这些电话号码一般是广告，或者是空号， 甚至可能是诈骗。
# [Sent-8][Claim: 0.617, Pattern: 0.799, Result: 0.690]	早在之前已有多地网警对该信息进行辟谣。
# [Sent-9][Claim: 0.000, Pattern: 0.000, Result: 0.000]	@咸宁网警巡查执法
